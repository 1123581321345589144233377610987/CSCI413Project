# %% [markdown]
# Type I Diabetes Data Cleaning

# %% [markdown]
# GitHub Repo (just in case):

# %%
# !pip install numpy
# !pip install scipy
# !pip install matplotlib
# !pip install librosa

# %%
from google.colab import drive
drive.mount('/content/drive/')
